# %% [markdown]
# # 05 CrossValidation Comparison

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_breast_cancer, make_classification
import numpy as np

data = load_breast_cancer()
X, y = data.data, data.target

# Small imbalanced dataset
X_small, y_small = make_classification(
    n_samples=25,
    n_classes=2,
    weights=[0.7, 0.3],
    random_state=42
)

print(f"Full Dataset: {X.shape}, Class Balance: {np.bincount(y)}")
print(f"Small Dataset: {X_small.shape}, Class Balance: {np.bincount(y_small)}")
# Out:
# Full Dataset: (569, 30), Class Balance: [212 357]
# Small Dataset: (25, 20), Class Balance: [18  7]

# %% [markdown]
# ## 1. Classical scikit-learn cross-validation
#
# ### 1.1 Stratified 5-Fold CV on the full dataset
#
# **Description (conceptual)**
#  This setup evaluates a model under a standard *stratified K-fold* regime:
#
# - The breast cancer dataset `X, y` is split into 5 folds.
# - In each fold, class proportions are preserved (stratification), which is important for slightly imbalanced binary problems.
# - A RandomForest is trained on 4 folds and evaluated on the remaining fold.
# - The process is repeated for all folds and the mean ± standard deviation of the accuracy is reported.
#
# This gives a robust estimate of how well the model generalizes under an IID assumption.

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(rf, X, y, cv=cv, scoring="accuracy")

print(f"sklearn StratifiedKFold(5) accuracy: {scores.mean():.3f} ± {scores.std():.3f}")
# Out:
# sklearn StratifiedKFold(5) accuracy: 0.956 ± 0.012

# %% [markdown]
# ### 1.3 Leave-P-Out CV (LPOCV, P=2) on the small dataset
#
# **Description (conceptual)**
#  Leave-P-Out CV is similar to LOOCV but leaves *P* points out in each fold:
#
# - Here `p=2`, so every possible pair of points is used as test set.
# - For `n=25`, this yields `C(25,2)=300` folds.
# - This is useful to understand stability under very small test sets but becomes combinatorially expensive for larger n.

# %%
from sklearn.model_selection import LeavePOut
from sklearn.linear_model import LogisticRegression

lpo = LeavePOut(p=2)
log_reg = LogisticRegression(max_iter=1000, solver="liblinear")

scores_lpo = cross_val_score(log_reg, X_small, y_small, cv=lpo, scoring="accuracy")

print(f"sklearn LPOCV (p=2) accuracy (X_small): {scores_lpo.mean():.3f}")
print(f"Number of folds (LPOCV): {len(scores_lpo)}")  # 300
# Out:
# sklearn LPOCV (p=2) accuracy (X_small): 0.913
# Number of folds (LPOCV): 300

# %% [markdown]
# ## 2. trustcv with TrustCVValidator (stratified K-fold + checks + CIs)
#
# Here we switch from “manual” CV loops to the **TrustCVValidator** abstraction you provided. This concentrates:
#
# - Choice of CV method (here: stratified K-fold).
# - Leakage and balance checks.
# - Metric aggregation (mean, std).
# - Confidence interval estimation (t-interval or bootstrap).
#
# ### 2.1 StratifiedKFoldMedical via TrustCVValidator
#
# **Description (conceptual)**
#
# In this setup:
#
# - We still use stratified 5-fold CV on the full breast cancer dataset `X, y`.
# - The `TrustCVValidator` orchestrates:
#   - Stratified splitting (`method="stratifiedKfold"`).
#   - Optional leakage and class-balance checks per fold.
#   - Computation of performance metrics (here at least accuracy by default; you can uncomment AUC, F1, etc.).
#   - Computation of **confidence intervals** for each metric using the chosen CI method (`t-interval` at 95%).
#
# The final `val_result.summary()` should print something like:
#
# - `accuracy: mean ± std, 95% CI [lower, upper]`
# - plus similar lines for any additional metrics you configure.

# %%
from sklearn.ensemble import RandomForestClassifier
from trustcv import TrustCVValidator

model = RandomForestClassifier(random_state=42)

validator = TrustCVValidator(
    method="stratifiedKfold",   # IID, stratified CV
    n_splits=5,
    random_state=42,
    shuffle=True,
    check_leakage=True,
    check_balance=True,
    # metrics=["accuracy", "roc_auc", "f1"],  # optionally specify metrics
    return_confidence_intervals=True,
    ci_method="t-interval",     # 'bootstrap' or 't-interval'
    ci_level=0.95,              # confidence level
)

val_result = validator.validate(model=model, X=X, y=y)
print(val_result.summary())
# Out:
# === Trustworthy Cross-Validation Results ===
#
# Performance Metrics (mean +/- std) (method: t-interval):
#   accuracy: 0.956 +/- 0.014 [95% CI (t-interval): 0.939-0.973]
#   roc_auc: 0.989 +/- 0.009 [95% CI (t-interval): 0.977-1.000]
#   sensitivity: 0.966 +/- 0.030 [95% CI (t-interval): 0.929-1.004]
#   specificity: 0.939 +/- 0.056 [95% CI (t-interval): 0.869-1.009]
#   precision: 0.965 +/- 0.031 [95% CI (t-interval): 0.926-1.004]
#   recall: 0.966 +/- 0.030 [95% CI (t-interval): 0.929-1.004]
#   f1: 0.965 +/- 0.011 [95% CI (t-interval): 0.952-0.979]
#
# Data Integrity Checks:
#   Leakage Check: PASSED
#   Class Balance: PASSED

# %% [markdown]
# ## 3. XGBoost CV on the full dataset
#
# **Description (conceptual)**
#
# This demonstrates how a boosting library’s **internal CV routine** works on the same data:
#
# - `xgboost.cv` performs K-fold CV inside XGBoost itself (no manual loops).
# - We use 5 stratified folds (`nfold=5`, `stratified=True`).
# - The function returns a table of metrics (training and validation loss/metrics per boosting round).
# - We typically look at the last row (or the best round) to report CV performance.

# %%
import xgboost as xgb

dtrain = xgb.DMatrix(X, label=y)

params = {
    "objective": "binary:logistic",
    "eval_metric": "error", # Changed from logloss to error
    "max_depth": 4,
    "eta": 0.1,
    "seed": 42,
}

cv_results_xgb_acc = xgb.cv(
    params=params,
    dtrain=dtrain,
    num_boost_round=200,
    nfold=5,
    stratified=True,
    seed=42,
    verbose_eval=False
)

# The 'error' metric is 1 - accuracy
mean_test_error = cv_results_xgb_acc['test-error-mean'].iloc[-1]
std_test_error = cv_results_xgb_acc['test-error-std'].iloc[-1]

mean_accuracy = 1 - mean_test_error
std_accuracy = std_test_error # Standard deviation of error is the same as standard deviation of accuracy

print(f"XGBoost 5-fold accuracy: {mean_accuracy:.3f} ± {std_accuracy:.3f}")
print("Full CV results (last row):")
print(cv_results_xgb_acc.tail(1))
# Out:
# XGBoost 5-fold accuracy: 0.960 ± 0.012
# Full CV results (last row):
#      train-error-mean  train-error-std  test-error-mean  test-error-std
# 199               0.0              0.0         0.040413        0.011872

# %% [markdown]
# ## 4. LightGBM CV with sklearn-generated folds
#
# **Description (conceptual)**
#
# Here we decouple the *fold generation* from the learning algorithm:
#
# - `StratifiedKFold` from sklearn defines which samples go in each train/test fold.
# - These indices are passed to `lightgbm.cv` via the `folds` argument.
# - This ensures:
#   - Same CV strategy as other models (e.g. RandomForest, XGBoost, trustcv).
#   - Direct comparability of results across different algorithms on identical folds.

# %%
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold

train_data = lgb.Dataset(X, label=y)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
folds = list(skf.split(X, y))

params = {
    "objective": "binary",
    "metric": "binary_error", # Changed metric to binary_error for accuracy
    "learning_rate": 0.05,
    "num_leaves": 31,
}

cv_results_lgb = lgb.cv(
    params=params,
    train_set=train_data,
    folds=folds,
    num_boost_round=200,
    seed=42
)

# The 'binary_error' metric is 1 - accuracy
mean_test_error_lgb = min(cv_results_lgb["valid binary_error-mean"])
std_test_error_lgb = cv_results_lgb["valid binary_error-stdv"][cv_results_lgb["valid binary_error-mean"].index(mean_test_error_lgb)]

mean_accuracy_lgb = 1 - mean_test_error_lgb
std_accuracy_lgb = std_test_error_lgb # Standard deviation of error is the same as standard deviation of accuracy

print(f"LightGBM 5-fold accuracy: {mean_accuracy_lgb:.3f} ± {std_accuracy_lgb:.3f}")
# Out:
# [LightGBM] [Info] Number of positive: 286, number of negative: 169
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5676
# [LightGBM] [Info] Number of data points in the train set: 455, number of used features: 30
# [LightGBM] [Info] Number of positive: 286, number of negative: 169
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5676
# [LightGBM] [Info] Number of data points in the train set: 455, number of used features: 30
# [LightGBM] [Info] Number of positive: 285, number of negative: 170
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000448 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5676
# [LightGBM] [Info] Number of data points in the train set: 455, number of used features: 30
# [LightGBM] [Info] Number of positive: 285, number of negative: 170
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000515 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5676
# [LightGBM] [Info] Number of data points in the train set: 455, number of used features: 30
# [LightGBM] [Info] Number of positive: 286, number of negative: 170
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000422 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5676
# [LightGBM] [Info] Number of data points in the train set: 456, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.628571 -> initscore=0.526093
# [LightGBM] [Info] Start training from score 0.526093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.628571 -> initscore=0.526093
# [LightGBM] [Info] Start training from score 0.526093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.626374 -> initscore=0.516691
# [LightGBM] [Info] Start training from score 0.516691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.626374 -> initscore=0.516691
# [LightGBM] [Info] Start training from score 0.516691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.627193 -> initscore=0.520193
# [LightGBM] [Info] Start training from score 0.520193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM 5-fold accuracy: 0.967 ± 0.018

# %% [markdown]
# ## 5. CatBoost CV on the full dataset
#
# **Description (conceptual)**
#
# CatBoost has its own CV mechanism:
#
# - `catboost.cv` performs K-fold CV directly on a `Pool`.
# - We use 5 folds, shuffling and stratifying labels.
# - The output is a table of metrics (e.g. AUC) over iterations.
# - As with XGBoost/LightGBM, we typically read off the final or best iteration.

# %%
from catboost import Pool, cv

pool = Pool(X, y)

params = {
    "loss_function": "Logloss",
    "eval_metric": "Accuracy", # Changed from AUC to Accuracy
    "iterations": 200,
    "learning_rate": 0.05,
    "depth": 4,
    "random_seed": 42,
}

cv_results_cb = cv(
    pool=pool,
    params=params,
    fold_count=5,
    shuffle=True,
    stratified=True
)

# Extract and print accuracy results
mean_test_accuracy_cb = cv_results_cb['test-Accuracy-mean'].iloc[-1]
std_test_accuracy_cb = cv_results_cb['test-Accuracy-std'].iloc[-1]

print(f"CatBoost 5-fold accuracy: {mean_test_accuracy_cb:.3f} \u00b1 {std_test_accuracy_cb:.3f}")
print("Full CV results (last row):")
print(cv_results_cb.tail(1))
# Out:
# Training on fold [0/5]
# 0:	learn: 0.9140969	test: 0.9304348	best: 0.9304348 (0)	total: 49.5ms	remaining: 9.86s
# 1:	learn: 0.9317181	test: 0.9304348	best: 0.9304348 (0)	total: 52.5ms	remaining: 5.2s
# 2:	learn: 0.9405286	test: 0.9043478	best: 0.9304348 (0)	total: 57.5ms	remaining: 3.78s
# 3:	learn: 0.9339207	test: 0.9217391	best: 0.9304348 (0)	total: 61.8ms	remaining: 3.03s
# 4:	learn: 0.9471366	test: 0.9217391	best: 0.9304348 (0)	total: 64ms	remaining: 2.5s
# 5:	learn: 0.9493392	test: 0.9217391	best: 0.9304348 (0)	total: 66.3ms	remaining: 2.15s
# 6:	learn: 0.9537445	test: 0.9217391	best: 0.9304348 (0)	total: 68.3ms	remaining: 1.88s
# 7:	learn: 0.9537445	test: 0.9217391	best: 0.9304348 (0)	total: 70.3ms	remaining: 1.69s
# 8:	learn: 0.9581498	test: 0.9304348	best: 0.9304348 (0)	total: 75.7ms	remaining: 1.61s
# 9:	learn: 0.9625551	test: 0.9304348	best: 0.9304348 (0)	total: 78.4ms	remaining: 1.49s
# 10:	learn: 0.9625551	test: 0.9391304	best: 0.9391304 (10)	total: 80.6ms	remaining: 1.38s
# 11:	learn: 0.9713656	test: 0.9391304	best: 0.9391304 (10)	total: 82.5ms	remaining: 1.29s
# 12:	learn: 0.9669604	test: 0.9478261	best: 0.9478261 (12)	total: 84.4ms	remaining: 1.21s
# 13:	learn: 0.9735683	test: 0.9565217	best: 0.9565217 (13)	total: 88.5ms	remaining: 1.18s
# 14:	learn: 0.9735683	test: 0.9652174	best: 0.9652174 (14)	total: 92.9ms	remaining: 1.15s
# 15:	learn: 0.9757709	test: 0.9565217	best: 0.9652174 (14)	total: 95.9ms	remaining: 1.1s
# 16:	learn: 0.9779736	test: 0.9652174	best: 0.9652174 (14)	total: 98.8ms	remaining: 1.06s
# 17:	learn: 0.9779736	test: 0.9652174	best: 0.9652174 (14)	total: 101ms	remaining: 1.02s
# 18:	learn: 0.9801762	test: 0.9652174	best: 0.9652174 (14)	total: 103ms	remaining: 984ms
# 19:	learn: 0.9779736	test: 0.9652174	best: 0.9652174 (14)	total: 108ms	remaining: 968ms
# 20:	learn: 0.9801762	test: 0.9652174	best: 0.9652174 (14)	total: 110ms	remaining: 939ms
# 21:	learn: 0.9779736	test: 0.9565217	best: 0.9652174 (14)	total: 112ms	remaining: 908ms
# 22:	learn: 0.9779736	test: 0.9565217	best: 0.9652174 (14)	total: 114ms	remaining: 877ms
# 23:	learn: 0.9823789	test: 0.9652174	best: 0.9652174 (14)	total: 116ms	remaining: 849ms
# 24:	learn: 0.9823789	test: 0.9565217	best: 0.9652174 (14)	total: 118ms	remaining: 823ms
# 25:	learn: 0.9823789	test: 0.9652174	best: 0.9652174 (14)	total: 121ms	remaining: 807ms
# 26:	learn: 0.9823789	test: 0.9565217	best: 0.9652174 (14)	total: 125ms	remaining: 803ms
# 27:	learn: 0.9823789	test: 0.9565217	best: 0.9652174 (14)	total: 128ms	remaining: 784ms
# 28:	learn: 0.9823789	test: 0.9565217	best: 0.9652174 (14)	total: 130ms	remaining: 764ms
# 29:	learn: 0.9845815	test: 0.9565217	best: 0.9652174 (14)	total: 132ms	remaining: 745ms
# 30:	learn: 0.9867841	test: 0.9565217	best: 0.9652174 (14)	total: 134ms	remaining: 730ms
# 31:	learn: 0.9867841	test: 0.9565217	best: 0.9652174 (14)	total: 139ms	remaining: 728ms
# 32:	learn: 0.9867841	test: 0.9565217	best: 0.9652174 (14)	total: 142ms	remaining: 717ms
# 33:	learn: 0.9867841	test: 0.9565217	best: 0.9652174 (14)	total: 144ms	remaining: 703ms
# 34:	learn: 0.9867841	test: 0.9565217	best: 0.9652174 (14)	total: 146ms	remaining: 690ms
# 35:	learn: 0.9867841	test: 0.9652174	best: 0.9652174 (14)	total: 149ms	remaining: 679ms
# 36:	learn: 0.9867841	test: 0.9652174	best: 0.9652174 (14)	total: 152ms	remaining: 672ms
# 37:	learn: 0.9867841	test: 0.9652174	best: 0.9652174 (14)	total: 156ms	remaining: 664ms
# 38:	learn: 0.9889868	test: 0.9652174	best: 0.9652174 (14)	total: 158ms	remaining: 654ms
# 39:	learn: 0.9867841	test: 0.9652174	best: 0.9652174 (14)	total: 160ms	remaining: 641ms
# 40:	learn: 0.9889868	test: 0.9652174	best: 0.9652174 (14)	total: 162ms	remaining: 628ms
# 41:	learn: 0.9889868	test: 0.9739130	best: 0.9739130 (41)	total: 164ms	remaining: 616ms
# 42:	learn: 0.9911894	test: 0.9739130	best: 0.9739130 (41)	total: 165ms	remaining: 604ms
# 43:	learn: 0.9911894	test: 0.9739130	best: 0.9739130 (41)	total: 169ms	remaining: 600ms
# 44:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 171ms	remaining: 590ms
# 45:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 174ms	remaining: 581ms
# 46:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 176ms	remaining: 573ms
# 47:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 180ms	remaining: 570ms
# 48:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 185ms	remaining: 569ms
# 49:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 189ms	remaining: 567ms
# 50:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 191ms	remaining: 558ms
# 51:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 194ms	remaining: 552ms
# 52:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 196ms	remaining: 545ms
# 53:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 198ms	remaining: 536ms
# 54:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 201ms	remaining: 530ms
# 55:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 205ms	remaining: 526ms
# 56:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 208ms	remaining: 522ms
# 57:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 210ms	remaining: 515ms
# 58:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (41)	total: 212ms	remaining: 507ms
# 59:	learn: 0.9933921	test: 0.9652174	best: 0.9739130 (41)	total: 214ms	remaining: 499ms
# 60:	learn: 0.9955947	test: 0.9652174	best: 0.9739130 (41)	total: 220ms	remaining: 502ms
# 61:	learn: 0.9955947	test: 0.9652174	best: 0.9739130 (41)	total: 224ms	remaining: 499ms
# 62:	learn: 0.9955947	test: 0.9652174	best: 0.9739130 (41)	total: 227ms	remaining: 493ms
# 63:	learn: 0.9955947	test: 0.9652174	best: 0.9739130 (41)	total: 229ms	remaining: 486ms
# 64:	learn: 0.9955947	test: 0.9652174	best: 0.9739130 (41)	total: 232ms	remaining: 482ms
# 65:	learn: 0.9955947	test: 0.9652174	best: 0.9739130 (41)	total: 234ms	remaining: 475ms
# 66:	learn: 0.9955947	test: 0.9652174	best: 0.9739130 (41)	total: 236ms	remaining: 469ms
# 67:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 238ms	remaining: 462ms
# 68:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 241ms	remaining: 457ms
# 69:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 244ms	remaining: 454ms
# 70:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 250ms	remaining: 454ms
# 71:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 253ms	remaining: 450ms
# 72:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 255ms	remaining: 444ms
# 73:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 258ms	remaining: 439ms
# 74:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 260ms	remaining: 433ms
# 75:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 262ms	remaining: 427ms
# 76:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 266ms	remaining: 424ms
# 77:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 268ms	remaining: 420ms
# 78:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 271ms	remaining: 415ms
# 79:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 273ms	remaining: 409ms
# 80:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 275ms	remaining: 404ms
# 81:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 277ms	remaining: 398ms
# 82:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 280ms	remaining: 395ms
# 83:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 283ms	remaining: 391ms
# 84:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 285ms	remaining: 386ms
# 85:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 287ms	remaining: 381ms
# 86:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 290ms	remaining: 376ms
# 87:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 291ms	remaining: 371ms
# 88:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 293ms	remaining: 366ms
# 89:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 297ms	remaining: 362ms
# 90:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 299ms	remaining: 358ms
# 91:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (41)	total: 301ms	remaining: 353ms
# 92:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 303ms	remaining: 349ms
# 93:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 305ms	remaining: 344ms
# 94:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 307ms	remaining: 339ms
# 95:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 309ms	remaining: 334ms
# 96:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 313ms	remaining: 333ms
# 97:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 316ms	remaining: 329ms
# 98:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 318ms	remaining: 324ms
# 99:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 320ms	remaining: 320ms
# 100:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 322ms	remaining: 316ms
# 101:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 324ms	remaining: 311ms
# 102:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 327ms	remaining: 308ms
# 103:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 329ms	remaining: 304ms
# 104:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 331ms	remaining: 300ms
# 105:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 334ms	remaining: 296ms
# 106:	learn: 0.9977974	test: 0.9739130	best: 0.9739130 (41)	total: 336ms	remaining: 292ms
# 107:	learn: 1.0000000	test: 0.9739130	best: 0.9739130 (41)	total: 338ms	remaining: 288ms
# 108:	learn: 1.0000000	test: 0.9739130	best: 0.9739130 (41)	total: 341ms	remaining: 284ms
# 109:	learn: 1.0000000	test: 0.9739130	best: 0.9739130 (41)	total: 345ms	remaining: 282ms
# 110:	learn: 1.0000000	test: 0.9739130	best: 0.9739130 (41)	total: 348ms	remaining: 279ms
# 111:	learn: 1.0000000	test: 0.9739130	best: 0.9739130 (41)	total: 351ms	remaining: 275ms
# 112:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 353ms	remaining: 272ms
# 113:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 355ms	remaining: 268ms
# 114:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 359ms	remaining: 265ms
# 115:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 361ms	remaining: 261ms
# 116:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 363ms	remaining: 258ms
# 117:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 365ms	remaining: 254ms
# 118:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 367ms	remaining: 250ms
# 119:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 370ms	remaining: 246ms
# 120:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 371ms	remaining: 243ms
# 121:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 375ms	remaining: 240ms
# 122:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 380ms	remaining: 238ms
# 123:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 383ms	remaining: 235ms
# 124:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 384ms	remaining: 231ms
# 125:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 386ms	remaining: 227ms
# 126:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 389ms	remaining: 224ms
# 127:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 391ms	remaining: 220ms
# 128:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 395ms	remaining: 217ms
# 129:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 398ms	remaining: 214ms
# 130:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 400ms	remaining: 211ms
# 131:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 402ms	remaining: 207ms
# 132:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 405ms	remaining: 204ms
# 133:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 409ms	remaining: 201ms
# 134:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 411ms	remaining: 198ms
# 135:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 414ms	remaining: 195ms
# 136:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 417ms	remaining: 192ms
# 137:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 423ms	remaining: 190ms
# 138:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 426ms	remaining: 187ms
# 139:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 429ms	remaining: 184ms
# 140:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 431ms	remaining: 180ms
# 141:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 432ms	remaining: 177ms
# 142:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 435ms	remaining: 173ms
# 143:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 440ms	remaining: 171ms
# 144:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 443ms	remaining: 168ms
# 145:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 446ms	remaining: 165ms
# 146:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 449ms	remaining: 162ms
# 147:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 453ms	remaining: 159ms
# 148:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 456ms	remaining: 156ms
# 149:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 458ms	remaining: 153ms
# 150:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 460ms	remaining: 149ms
# 151:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 462ms	remaining: 146ms
# 152:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 464ms	remaining: 143ms
# 153:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 466ms	remaining: 139ms
# 154:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 470ms	remaining: 136ms
# 155:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 473ms	remaining: 133ms
# 156:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 475ms	remaining: 130ms
# 157:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 478ms	remaining: 127ms
# 158:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 481ms	remaining: 124ms
# 159:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 483ms	remaining: 121ms
# 160:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 487ms	remaining: 118ms
# 161:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 490ms	remaining: 115ms
# 162:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 491ms	remaining: 112ms
# 163:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 493ms	remaining: 108ms
# 164:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 495ms	remaining: 105ms
# 165:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 497ms	remaining: 102ms
# 166:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 501ms	remaining: 98.9ms
# 167:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 503ms	remaining: 95.9ms
# 168:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 506ms	remaining: 92.8ms
# 169:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 509ms	remaining: 89.7ms
# 170:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 511ms	remaining: 86.7ms
# 171:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 514ms	remaining: 83.6ms
# 172:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 518ms	remaining: 80.8ms
# 173:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 520ms	remaining: 77.7ms
# 174:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 522ms	remaining: 74.6ms
# 175:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 524ms	remaining: 71.5ms
# 176:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 526ms	remaining: 68.3ms
# 177:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 528ms	remaining: 65.2ms
# 178:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 530ms	remaining: 62.2ms
# 179:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 536ms	remaining: 59.5ms
# 180:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 538ms	remaining: 56.5ms
# 181:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 540ms	remaining: 53.4ms
# 182:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 542ms	remaining: 50.4ms
# 183:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 544ms	remaining: 47.3ms
# 184:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 546ms	remaining: 44.2ms
# 185:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 550ms	remaining: 41.4ms
# 186:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (112)	total: 553ms	remaining: 38.4ms
# 187:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 555ms	remaining: 35.4ms
# 188:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 557ms	remaining: 32.4ms
# 189:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 559ms	remaining: 29.4ms
# 190:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 561ms	remaining: 26.4ms
# 191:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 563ms	remaining: 23.5ms
# 192:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 566ms	remaining: 20.5ms
# 193:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 569ms	remaining: 17.6ms
# 194:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 573ms	remaining: 14.7ms
# 195:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 575ms	remaining: 11.7ms
# 196:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 577ms	remaining: 8.79ms
# 197:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 581ms	remaining: 5.87ms
# 198:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 584ms	remaining: 2.94ms
# 199:	learn: 1.0000000	test: 0.9739130	best: 0.9826087 (112)	total: 586ms	remaining: 0us
#
# bestTest = 0.9826086957
# bestIteration = 112
#
# Training on fold [1/5]
# 0:	learn: 0.9162996	test: 0.9217391	best: 0.9217391 (0)	total: 3.09ms	remaining: 614ms
# 1:	learn: 0.9361233	test: 0.9478261	best: 0.9478261 (1)	total: 5.11ms	remaining: 505ms
# 2:	learn: 0.9361233	test: 0.9478261	best: 0.9478261 (1)	total: 6.87ms	remaining: 451ms
# 3:	learn: 0.9361233	test: 0.9217391	best: 0.9478261 (1)	total: 8.68ms	remaining: 425ms
# 4:	learn: 0.9383260	test: 0.9304348	best: 0.9478261 (1)	total: 10.5ms	remaining: 409ms
# 5:	learn: 0.9537445	test: 0.9739130	best: 0.9739130 (5)	total: 15.1ms	remaining: 487ms
# 6:	learn: 0.9537445	test: 0.9739130	best: 0.9739130 (5)	total: 17.3ms	remaining: 477ms
# 7:	learn: 0.9471366	test: 0.9739130	best: 0.9739130 (5)	total: 19.2ms	remaining: 460ms
# 8:	learn: 0.9581498	test: 0.9478261	best: 0.9739130 (5)	total: 21ms	remaining: 447ms
# 9:	learn: 0.9647577	test: 0.9478261	best: 0.9739130 (5)	total: 23ms	remaining: 436ms
# 10:	learn: 0.9669604	test: 0.9391304	best: 0.9739130 (5)	total: 24.8ms	remaining: 426ms
# 11:	learn: 0.9647577	test: 0.9391304	best: 0.9739130 (5)	total: 28.5ms	remaining: 446ms
# 12:	learn: 0.9647577	test: 0.9391304	best: 0.9739130 (5)	total: 31.5ms	remaining: 453ms
# 13:	learn: 0.9691630	test: 0.9652174	best: 0.9739130 (5)	total: 34.7ms	remaining: 461ms
# 14:	learn: 0.9757709	test: 0.9652174	best: 0.9739130 (5)	total: 37.1ms	remaining: 458ms
# 15:	learn: 0.9713656	test: 0.9739130	best: 0.9739130 (5)	total: 39.1ms	remaining: 450ms
# 16:	learn: 0.9757709	test: 0.9652174	best: 0.9739130 (5)	total: 41ms	remaining: 441ms
# 17:	learn: 0.9779736	test: 0.9652174	best: 0.9739130 (5)	total: 43.7ms	remaining: 442ms
# 18:	learn: 0.9801762	test: 0.9739130	best: 0.9739130 (5)	total: 46.3ms	remaining: 441ms
# 19:	learn: 0.9801762	test: 0.9739130	best: 0.9739130 (5)	total: 49.6ms	remaining: 446ms
# 20:	learn: 0.9823789	test: 0.9739130	best: 0.9739130 (5)	total: 51.8ms	remaining: 441ms
# 21:	learn: 0.9823789	test: 0.9739130	best: 0.9739130 (5)	total: 53.7ms	remaining: 434ms
# 22:	learn: 0.9823789	test: 0.9739130	best: 0.9739130 (5)	total: 55.5ms	remaining: 427ms
# 23:	learn: 0.9823789	test: 0.9652174	best: 0.9739130 (5)	total: 57.2ms	remaining: 420ms
# 24:	learn: 0.9823789	test: 0.9652174	best: 0.9739130 (5)	total: 60.3ms	remaining: 422ms
# 25:	learn: 0.9823789	test: 0.9652174	best: 0.9739130 (5)	total: 62.9ms	remaining: 421ms
# 26:	learn: 0.9845815	test: 0.9565217	best: 0.9739130 (5)	total: 66.3ms	remaining: 425ms
# 27:	learn: 0.9867841	test: 0.9565217	best: 0.9739130 (5)	total: 68.5ms	remaining: 421ms
# 28:	learn: 0.9845815	test: 0.9739130	best: 0.9739130 (5)	total: 70.5ms	remaining: 415ms
# 29:	learn: 0.9845815	test: 0.9739130	best: 0.9739130 (5)	total: 72.3ms	remaining: 410ms
# 30:	learn: 0.9845815	test: 0.9739130	best: 0.9739130 (5)	total: 76ms	remaining: 414ms
# 31:	learn: 0.9845815	test: 0.9739130	best: 0.9739130 (5)	total: 78.5ms	remaining: 412ms
# 32:	learn: 0.9867841	test: 0.9652174	best: 0.9739130 (5)	total: 81ms	remaining: 410ms
# 33:	learn: 0.9845815	test: 0.9652174	best: 0.9739130 (5)	total: 83ms	remaining: 405ms
# 34:	learn: 0.9889868	test: 0.9652174	best: 0.9739130 (5)	total: 85.2ms	remaining: 402ms
# 35:	learn: 0.9889868	test: 0.9652174	best: 0.9739130 (5)	total: 87ms	remaining: 396ms
# 36:	learn: 0.9889868	test: 0.9652174	best: 0.9739130 (5)	total: 88.8ms	remaining: 391ms
# 37:	learn: 0.9889868	test: 0.9652174	best: 0.9739130 (5)	total: 91.8ms	remaining: 392ms
# 38:	learn: 0.9889868	test: 0.9652174	best: 0.9739130 (5)	total: 94.5ms	remaining: 390ms
# 39:	learn: 0.9889868	test: 0.9652174	best: 0.9739130 (5)	total: 97ms	remaining: 388ms
# 40:	learn: 0.9889868	test: 0.9652174	best: 0.9739130 (5)	total: 99.2ms	remaining: 385ms
# 41:	learn: 0.9911894	test: 0.9652174	best: 0.9739130 (5)	total: 101ms	remaining: 382ms
# 42:	learn: 0.9911894	test: 0.9652174	best: 0.9739130 (5)	total: 103ms	remaining: 378ms
# 43:	learn: 0.9911894	test: 0.9652174	best: 0.9739130 (5)	total: 105ms	remaining: 374ms
# 44:	learn: 0.9933921	test: 0.9652174	best: 0.9739130 (5)	total: 109ms	remaining: 375ms
# 45:	learn: 0.9911894	test: 0.9739130	best: 0.9739130 (5)	total: 112ms	remaining: 373ms
# 46:	learn: 0.9933921	test: 0.9652174	best: 0.9739130 (5)	total: 114ms	remaining: 370ms
# 47:	learn: 0.9933921	test: 0.9652174	best: 0.9739130 (5)	total: 116ms	remaining: 366ms
# 48:	learn: 0.9933921	test: 0.9652174	best: 0.9739130 (5)	total: 117ms	remaining: 362ms
# 49:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 119ms	remaining: 358ms
# 50:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 121ms	remaining: 354ms
# 51:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 126ms	remaining: 358ms
# 52:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 129ms	remaining: 358ms
# 53:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 132ms	remaining: 357ms
# 54:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 134ms	remaining: 353ms
# 55:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 136ms	remaining: 350ms
# 56:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 140ms	remaining: 351ms
# 57:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 142ms	remaining: 348ms
# 58:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 145ms	remaining: 346ms
# 59:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 147ms	remaining: 343ms
# 60:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 149ms	remaining: 339ms
# 61:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 151ms	remaining: 335ms
# 62:	learn: 0.9933921	test: 0.9739130	best: 0.9739130 (5)	total: 152ms	remaining: 331ms
# 63:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 156ms	remaining: 332ms
# 64:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 159ms	remaining: 329ms
# 65:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 161ms	remaining: 327ms
# 66:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 163ms	remaining: 324ms
# 67:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 165ms	remaining: 321ms
# 68:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 169ms	remaining: 321ms
# 69:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 173ms	remaining: 322ms
# 70:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 177ms	remaining: 321ms
# 71:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 180ms	remaining: 320ms
# 72:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 182ms	remaining: 316ms
# 73:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 184ms	remaining: 313ms
# 74:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 187ms	remaining: 311ms
# 75:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 189ms	remaining: 309ms
# 76:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 192ms	remaining: 307ms
# 77:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 194ms	remaining: 303ms
# 78:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 196ms	remaining: 300ms
# 79:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 198ms	remaining: 296ms
# 80:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 199ms	remaining: 293ms
# 81:	learn: 0.9955947	test: 0.9739130	best: 0.9739130 (5)	total: 203ms	remaining: 292ms
# 82:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 206ms	remaining: 290ms
# 83:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 208ms	remaining: 288ms
# 84:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 211ms	remaining: 285ms
# 85:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 213ms	remaining: 283ms
# 86:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 216ms	remaining: 280ms
# 87:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 220ms	remaining: 280ms
# 88:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 223ms	remaining: 278ms
# 89:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 225ms	remaining: 276ms
# 90:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 228ms	remaining: 273ms
# 91:	learn: 0.9955947	test: 0.9739130	best: 0.9826087 (82)	total: 230ms	remaining: 270ms
# 92:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 232ms	remaining: 267ms
# 93:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 236ms	remaining: 266ms
# 94:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 238ms	remaining: 263ms
# 95:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 241ms	remaining: 261ms
# 96:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 242ms	remaining: 257ms
# 97:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 244ms	remaining: 254ms
# 98:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 246ms	remaining: 251ms
# 99:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 248ms	remaining: 248ms
# 100:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 253ms	remaining: 248ms
# 101:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 255ms	remaining: 245ms
# 102:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 258ms	remaining: 243ms
# 103:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 261ms	remaining: 241ms
# 104:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 263ms	remaining: 238ms
# 105:	learn: 0.9955947	test: 0.9826087	best: 0.9826087 (82)	total: 267ms	remaining: 237ms
# 106:	learn: 0.9977974	test: 0.9826087	best: 0.9826087 (82)	total: 269ms	remaining: 234ms
# 107:	learn: 0.9977974	test: 0.9826087	best: 0.9826087 (82)	total: 272ms	remaining: 231ms
# 108:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 274ms	remaining: 228ms
# 109:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 275ms	remaining: 225ms
# 110:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 278ms	remaining: 223ms
# 111:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 280ms	remaining: 220ms
# 112:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 284ms	remaining: 218ms
# 113:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 287ms	remaining: 216ms
# 114:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 289ms	remaining: 214ms
# 115:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 292ms	remaining: 211ms
# 116:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 294ms	remaining: 209ms
# 117:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 298ms	remaining: 207ms
# 118:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 301ms	remaining: 205ms
# 119:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 303ms	remaining: 202ms
# 120:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 305ms	remaining: 199ms
# 121:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 307ms	remaining: 197ms
# 122:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 310ms	remaining: 194ms
# 123:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 313ms	remaining: 192ms
# 124:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 316ms	remaining: 190ms
# 125:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 319ms	remaining: 188ms
# 126:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 322ms	remaining: 185ms
# 127:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 324ms	remaining: 182ms
# 128:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 326ms	remaining: 179ms
# 129:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 329ms	remaining: 177ms
# 130:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 332ms	remaining: 175ms
# 131:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 335ms	remaining: 172ms
# 132:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 338ms	remaining: 170ms
# 133:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 340ms	remaining: 167ms
# 134:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 341ms	remaining: 164ms
# 135:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 344ms	remaining: 162ms
# 136:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 348ms	remaining: 160ms
# 137:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 350ms	remaining: 157ms
# 138:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 352ms	remaining: 155ms
# 139:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 354ms	remaining: 152ms
# 140:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 356ms	remaining: 149ms
# 141:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 361ms	remaining: 148ms
# 142:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 365ms	remaining: 145ms
# 143:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 367ms	remaining: 143ms
# 144:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 370ms	remaining: 140ms
# 145:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 372ms	remaining: 138ms
# 146:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 374ms	remaining: 135ms
# 147:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 377ms	remaining: 132ms
# 148:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 380ms	remaining: 130ms
# 149:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 382ms	remaining: 127ms
# 150:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 384ms	remaining: 125ms
# 151:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 386ms	remaining: 122ms
# 152:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 388ms	remaining: 119ms
# 153:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 390ms	remaining: 116ms
# 154:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 394ms	remaining: 114ms
# 155:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 396ms	remaining: 112ms
# 156:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 398ms	remaining: 109ms
# 157:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 400ms	remaining: 106ms
# 158:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 402ms	remaining: 104ms
# 159:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 404ms	remaining: 101ms
# 160:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 406ms	remaining: 98.2ms
# 161:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 410ms	remaining: 96.2ms
# 162:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 413ms	remaining: 93.8ms
# 163:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 416ms	remaining: 91.3ms
# 164:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 418ms	remaining: 88.7ms
# 165:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 420ms	remaining: 86ms
# 166:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 422ms	remaining: 83.4ms
# 167:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 426ms	remaining: 81.2ms
# 168:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 429ms	remaining: 78.7ms
# 169:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 432ms	remaining: 76.2ms
# 170:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 434ms	remaining: 73.7ms
# 171:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 437ms	remaining: 71.1ms
# 172:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 442ms	remaining: 68.9ms
# 173:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 444ms	remaining: 66.4ms
# 174:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 447ms	remaining: 63.8ms
# 175:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 449ms	remaining: 61.3ms
# 176:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 452ms	remaining: 58.7ms
# 177:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 454ms	remaining: 56.1ms
# 178:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 457ms	remaining: 53.6ms
# 179:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 461ms	remaining: 51.2ms
# 180:	learn: 1.0000000	test: 0.9826087	best: 0.9826087 (82)	total: 463ms	remaining: 48.6ms
# 181:	learn: 1.0000000	test: 0.9913043	best: 0.9913043 (181)	total: 465ms	remaining: 46ms
# 182:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 467ms	remaining: 43.3ms
# 183:	learn: 1.0000000	test: 0.9913043	best: 0.9913043 (181)	total: 469ms	remaining: 40.7ms
# 184:	learn: 1.0000000	test: 0.9913043	best: 0.9913043 (181)	total: 472ms	remaining: 38.3ms
# 185:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 475ms	remaining: 35.8ms
# 186:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 478ms	remaining: 33.3ms
# 187:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 480ms	remaining: 30.6ms
# 188:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 482ms	remaining: 28.1ms
# 189:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 484ms	remaining: 25.5ms
# 190:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 487ms	remaining: 22.9ms
# 191:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 490ms	remaining: 20.4ms
# 192:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 492ms	remaining: 17.8ms
# 193:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 494ms	remaining: 15.3ms
# 194:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 496ms	remaining: 12.7ms
# 195:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 497ms	remaining: 10.1ms
# 196:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 499ms	remaining: 7.6ms
# 197:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 503ms	remaining: 5.08ms
# 198:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 505ms	remaining: 2.54ms
# 199:	learn: 1.0000000	test: 0.9826087	best: 0.9913043 (181)	total: 508ms	remaining: 0us
#
# bestTest = 0.9913043478
# bestIteration = 181
#
# Training on fold [2/5]
# 0:	learn: 0.9276316	test: 0.8938053	best: 0.8938053 (0)	total: 4.59ms	remaining: 913ms
# 1:	learn: 0.9429825	test: 0.9026549	best: 0.9026549 (1)	total: 6.79ms	remaining: 672ms
# 2:	learn: 0.9429825	test: 0.9203540	best: 0.9203540 (2)	total: 9.05ms	remaining: 594ms
# 3:	learn: 0.9473684	test: 0.9115044	best: 0.9203540 (2)	total: 12.6ms	remaining: 618ms
# 4:	learn: 0.9495614	test: 0.9203540	best: 0.9203540 (2)	total: 17.6ms	remaining: 688ms
# 5:	learn: 0.9539474	test: 0.9115044	best: 0.9203540 (2)	total: 20.5ms	remaining: 664ms
# 6:	learn: 0.9583333	test: 0.9292035	best: 0.9292035 (6)	total: 23.3ms	remaining: 644ms
# 7:	learn: 0.9583333	test: 0.9203540	best: 0.9292035 (6)	total: 26ms	remaining: 623ms
# 8:	learn: 0.9605263	test: 0.9292035	best: 0.9292035 (6)	total: 28.6ms	remaining: 607ms
# 9:	learn: 0.9649123	test: 0.9292035	best: 0.9292035 (6)	total: 34.1ms	remaining: 647ms
# 10:	learn: 0.9605263	test: 0.9292035	best: 0.9292035 (6)	total: 39.7ms	remaining: 683ms
# 11:	learn: 0.9605263	test: 0.9380531	best: 0.9380531 (11)	total: 42.5ms	remaining: 666ms
# 12:	learn: 0.9627193	test: 0.9380531	best: 0.9380531 (11)	total: 45.7ms	remaining: 658ms
# 13:	learn: 0.9692982	test: 0.9469027	best: 0.9469027 (13)	total: 50.9ms	remaining: 677ms
# 14:	learn: 0.9671053	test: 0.9469027	best: 0.9469027 (13)	total: 54.1ms	remaining: 667ms
# 15:	learn: 0.9692982	test: 0.9469027	best: 0.9469027 (13)	total: 57.3ms	remaining: 659ms
# 16:	learn: 0.9736842	test: 0.9469027	best: 0.9469027 (13)	total: 60ms	remaining: 646ms
# 17:	learn: 0.9780702	test: 0.9469027	best: 0.9469027 (13)	total: 64.5ms	remaining: 653ms
# 18:	learn: 0.9824561	test: 0.9557522	best: 0.9557522 (18)	total: 69ms	remaining: 657ms
# 19:	learn: 0.9824561	test: 0.9557522	best: 0.9557522 (18)	total: 72.2ms	remaining: 650ms
# 20:	learn: 0.9824561	test: 0.9469027	best: 0.9557522 (18)	total: 78.6ms	remaining: 670ms
# 21:	learn: 0.9824561	test: 0.9557522	best: 0.9557522 (18)	total: 83.7ms	remaining: 677ms
# 22:	learn: 0.9846491	test: 0.9557522	best: 0.9557522 (18)	total: 87.3ms	remaining: 672ms
# 23:	learn: 0.9824561	test: 0.9557522	best: 0.9557522 (18)	total: 91ms	remaining: 667ms
# 24:	learn: 0.9846491	test: 0.9557522	best: 0.9557522 (18)	total: 94.9ms	remaining: 664ms
# 25:	learn: 0.9824561	test: 0.9557522	best: 0.9557522 (18)	total: 98.2ms	remaining: 657ms
# 26:	learn: 0.9846491	test: 0.9557522	best: 0.9557522 (18)	total: 101ms	remaining: 646ms
# 27:	learn: 0.9846491	test: 0.9557522	best: 0.9557522 (18)	total: 104ms	remaining: 638ms
# 28:	learn: 0.9846491	test: 0.9557522	best: 0.9557522 (18)	total: 106ms	remaining: 626ms
# 29:	learn: 0.9846491	test: 0.9557522	best: 0.9557522 (18)	total: 110ms	remaining: 626ms
# 30:	learn: 0.9846491	test: 0.9557522	best: 0.9557522 (18)	total: 114ms	remaining: 619ms
# 31:	learn: 0.9868421	test: 0.9557522	best: 0.9557522 (18)	total: 117ms	remaining: 612ms
# 32:	learn: 0.9846491	test: 0.9557522	best: 0.9557522 (18)	total: 119ms	remaining: 601ms
# 33:	learn: 0.9868421	test: 0.9557522	best: 0.9557522 (18)	total: 121ms	remaining: 592ms
# 34:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 124ms	remaining: 583ms
# 35:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 127ms	remaining: 580ms
# 36:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 131ms	remaining: 575ms
# 37:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 134ms	remaining: 571ms
# 38:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 137ms	remaining: 564ms
# 39:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 139ms	remaining: 556ms
# 40:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 144ms	remaining: 558ms
# 41:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 147ms	remaining: 553ms
# 42:	learn: 0.9890351	test: 0.9646018	best: 0.9646018 (34)	total: 149ms	remaining: 545ms
# 43:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 151ms	remaining: 537ms
# 44:	learn: 0.9868421	test: 0.9646018	best: 0.9646018 (34)	total: 155ms	remaining: 532ms
# 45:	learn: 0.9890351	test: 0.9646018	best: 0.9646018 (34)	total: 159ms	remaining: 531ms
# 46:	learn: 0.9912281	test: 0.9646018	best: 0.9646018 (34)	total: 162ms	remaining: 529ms
# 47:	learn: 0.9934211	test: 0.9646018	best: 0.9646018 (34)	total: 165ms	remaining: 524ms
# 48:	learn: 0.9934211	test: 0.9646018	best: 0.9646018 (34)	total: 168ms	remaining: 518ms
# 49:	learn: 0.9934211	test: 0.9646018	best: 0.9646018 (34)	total: 171ms	remaining: 513ms
# 50:	learn: 0.9934211	test: 0.9734513	best: 0.9734513 (50)	total: 176ms	remaining: 514ms
# 51:	learn: 0.9934211	test: 0.9734513	best: 0.9734513 (50)	total: 179ms	remaining: 509ms
# 52:	learn: 0.9934211	test: 0.9734513	best: 0.9734513 (50)	total: 182ms	remaining: 504ms
# 53:	learn: 0.9934211	test: 0.9734513	best: 0.9734513 (50)	total: 185ms	remaining: 499ms
# 54:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 188ms	remaining: 495ms
# 55:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 192ms	remaining: 493ms
# 56:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 194ms	remaining: 487ms
# 57:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 197ms	remaining: 482ms
# 58:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 200ms	remaining: 478ms
# 59:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 203ms	remaining: 474ms
# 60:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 208ms	remaining: 475ms
# 61:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 212ms	remaining: 473ms
# 62:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 215ms	remaining: 468ms
# 63:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 218ms	remaining: 464ms
# 64:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 222ms	remaining: 461ms
# 65:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 227ms	remaining: 460ms
# 66:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 229ms	remaining: 456ms
# 67:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 232ms	remaining: 450ms
# 68:	learn: 0.9956140	test: 0.9734513	best: 0.9734513 (50)	total: 235ms	remaining: 446ms
# 69:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 238ms	remaining: 443ms
# 70:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 242ms	remaining: 439ms
# 71:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 244ms	remaining: 434ms
# 72:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 247ms	remaining: 429ms
# 73:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 250ms	remaining: 425ms
# 74:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 255ms	remaining: 424ms
# 75:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 261ms	remaining: 426ms
# 76:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 265ms	remaining: 423ms
# 77:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 269ms	remaining: 420ms
# 78:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 273ms	remaining: 417ms
# 79:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 276ms	remaining: 414ms
# 80:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 280ms	remaining: 411ms
# 81:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 283ms	remaining: 407ms
# 82:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 288ms	remaining: 406ms
# 83:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 291ms	remaining: 402ms
# 84:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 294ms	remaining: 397ms
# 85:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 296ms	remaining: 392ms
# 86:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 297ms	remaining: 386ms
# 87:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 302ms	remaining: 384ms
# 88:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 305ms	remaining: 380ms
# 89:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 308ms	remaining: 376ms
# 90:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 310ms	remaining: 371ms
# 91:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 312ms	remaining: 366ms
# 92:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 314ms	remaining: 362ms
# 93:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 319ms	remaining: 360ms
# 94:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 323ms	remaining: 357ms
# 95:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 325ms	remaining: 352ms
# 96:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 327ms	remaining: 347ms
# 97:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 330ms	remaining: 343ms
# 98:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 334ms	remaining: 341ms
# 99:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 338ms	remaining: 338ms
# 100:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 340ms	remaining: 334ms
# 101:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 342ms	remaining: 329ms
# 102:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 345ms	remaining: 325ms
# 103:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 349ms	remaining: 322ms
# 104:	learn: 0.9978070	test: 0.9734513	best: 0.9734513 (50)	total: 352ms	remaining: 318ms
# 105:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 355ms	remaining: 315ms
# 106:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 358ms	remaining: 311ms
# 107:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 360ms	remaining: 307ms
# 108:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 365ms	remaining: 305ms
# 109:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 368ms	remaining: 301ms
# 110:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 370ms	remaining: 297ms
# 111:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 372ms	remaining: 292ms
# 112:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 375ms	remaining: 289ms
# 113:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 380ms	remaining: 287ms
# 114:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 385ms	remaining: 285ms
# 115:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 387ms	remaining: 280ms
# 116:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 390ms	remaining: 277ms
# 117:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 392ms	remaining: 273ms
# 118:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 397ms	remaining: 271ms
# 119:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 401ms	remaining: 267ms
# 120:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 403ms	remaining: 263ms
# 121:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 406ms	remaining: 260ms
# 122:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 408ms	remaining: 256ms
# 123:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 412ms	remaining: 253ms
# 124:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 415ms	remaining: 249ms
# 125:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 418ms	remaining: 245ms
# 126:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 421ms	remaining: 242ms
# 127:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 423ms	remaining: 238ms
# 128:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 426ms	remaining: 235ms
# 129:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 431ms	remaining: 232ms
# 130:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 434ms	remaining: 229ms
# 131:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 437ms	remaining: 225ms
# 132:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 438ms	remaining: 221ms
# 133:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 441ms	remaining: 217ms
# 134:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 445ms	remaining: 214ms
# 135:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 448ms	remaining: 211ms
# 136:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 450ms	remaining: 207ms
# 137:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 452ms	remaining: 203ms
# 138:	learn: 1.0000000	test: 0.9734513	best: 0.9734513 (50)	total: 455ms	remaining: 199ms
# ...
# 26:	learn: 0.9912281	test: 0.9203540	best: 0.9292035 (4)	total: 72.1ms	remaining: 462ms
# 27:	learn: 0.9912281	test: 0.9203540	best: 0.9292035 (4)	total: 74.6ms	remaining: 458ms
# 28:	learn: 0.9912281	test: 0.9292035	best: 0.9292035 (4)	total: 77.2ms	remaining: 455ms
# 29:	learn: 0.9912281	test: 0.9469027	best: 0.9469027 (29)	total: 79.9ms	remaining: 453ms
# 30:	learn: 0.9912281	test: 0.9469027	best: 0.9469027 (29)	total: 83ms	remaining: 453ms
# 31:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 85.4ms	remaining: 448ms
# 32:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 87.8ms	remaining: 444ms
# 33:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 90.3ms	remaining: 441ms
# 34:	learn: 0.9912281	test: 0.9469027	best: 0.9469027 (29)	total: 93.2ms	remaining: 439ms
# 35:	learn: 0.9912281	test: 0.9292035	best: 0.9469027 (29)	total: 96.1ms	remaining: 438ms
# 36:	learn: 0.9912281	test: 0.9203540	best: 0.9469027 (29)	total: 101ms	remaining: 444ms
# 37:	learn: 0.9912281	test: 0.9203540	best: 0.9469027 (29)	total: 104ms	remaining: 444ms
# 38:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 106ms	remaining: 439ms
# 39:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 108ms	remaining: 433ms
# 40:	learn: 0.9912281	test: 0.9292035	best: 0.9469027 (29)	total: 110ms	remaining: 428ms
# 41:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 113ms	remaining: 425ms
# 42:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 118ms	remaining: 429ms
# 43:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 121ms	remaining: 430ms
# 44:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 125ms	remaining: 430ms
# 45:	learn: 0.9912281	test: 0.9469027	best: 0.9469027 (29)	total: 128ms	remaining: 429ms
# 46:	learn: 0.9912281	test: 0.9469027	best: 0.9469027 (29)	total: 133ms	remaining: 432ms
# 47:	learn: 0.9912281	test: 0.9469027	best: 0.9469027 (29)	total: 138ms	remaining: 438ms
# 48:	learn: 0.9912281	test: 0.9469027	best: 0.9469027 (29)	total: 149ms	remaining: 458ms
# 49:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 161ms	remaining: 482ms
# 50:	learn: 0.9912281	test: 0.9292035	best: 0.9469027 (29)	total: 170ms	remaining: 496ms
# 51:	learn: 0.9912281	test: 0.9292035	best: 0.9469027 (29)	total: 200ms	remaining: 568ms
# 52:	learn: 0.9912281	test: 0.9292035	best: 0.9469027 (29)	total: 212ms	remaining: 589ms
# 53:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 230ms	remaining: 621ms
# 54:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 241ms	remaining: 636ms
# 55:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 262ms	remaining: 673ms
# 56:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 275ms	remaining: 689ms
# 57:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 301ms	remaining: 737ms
# 58:	learn: 0.9912281	test: 0.9292035	best: 0.9469027 (29)	total: 313ms	remaining: 748ms
# 59:	learn: 0.9912281	test: 0.9380531	best: 0.9469027 (29)	total: 320ms	remaining: 747ms
# 60:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 327ms	remaining: 745ms
# 61:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 338ms	remaining: 752ms
# 62:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 347ms	remaining: 755ms
# 63:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 359ms	remaining: 764ms
# 64:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 373ms	remaining: 774ms
# 65:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 381ms	remaining: 774ms
# 66:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 388ms	remaining: 771ms
# 67:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 401ms	remaining: 779ms
# 68:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 417ms	remaining: 792ms
# 69:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 422ms	remaining: 784ms
# 70:	learn: 0.9934211	test: 0.9380531	best: 0.9469027 (29)	total: 431ms	remaining: 782ms
# 71:	learn: 0.9956140	test: 0.9380531	best: 0.9469027 (29)	total: 436ms	remaining: 776ms
# 72:	learn: 0.9956140	test: 0.9380531	best: 0.9469027 (29)	total: 446ms	remaining: 776ms
# 73:	learn: 0.9956140	test: 0.9469027	best: 0.9469027 (29)	total: 453ms	remaining: 772ms
# 74:	learn: 0.9956140	test: 0.9469027	best: 0.9469027 (29)	total: 461ms	remaining: 768ms
# 75:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 468ms	remaining: 764ms
# 76:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 472ms	remaining: 755ms
# 77:	learn: 0.9956140	test: 0.9469027	best: 0.9557522 (75)	total: 476ms	remaining: 744ms
# 78:	learn: 0.9956140	test: 0.9469027	best: 0.9557522 (75)	total: 479ms	remaining: 734ms
# 79:	learn: 0.9956140	test: 0.9469027	best: 0.9557522 (75)	total: 484ms	remaining: 727ms
# 80:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 487ms	remaining: 716ms
# 81:	learn: 0.9956140	test: 0.9469027	best: 0.9557522 (75)	total: 491ms	remaining: 706ms
# 82:	learn: 0.9956140	test: 0.9469027	best: 0.9557522 (75)	total: 494ms	remaining: 697ms
# 83:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 498ms	remaining: 687ms
# 84:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 501ms	remaining: 678ms
# 85:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 506ms	remaining: 670ms
# 86:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 508ms	remaining: 660ms
# 87:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 511ms	remaining: 650ms
# 88:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 513ms	remaining: 640ms
# 89:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 516ms	remaining: 631ms
# 90:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 520ms	remaining: 623ms
# 91:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 523ms	remaining: 614ms
# 92:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 526ms	remaining: 605ms
# 93:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 530ms	remaining: 597ms
# 94:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 533ms	remaining: 589ms
# 95:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 538ms	remaining: 583ms
# 96:	learn: 0.9956140	test: 0.9557522	best: 0.9557522 (75)	total: 541ms	remaining: 574ms
# 97:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 544ms	remaining: 566ms
# 98:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 546ms	remaining: 557ms
# 99:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 549ms	remaining: 549ms
# 100:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 553ms	remaining: 543ms
# 101:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 557ms	remaining: 536ms
# 102:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 561ms	remaining: 528ms
# 103:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 564ms	remaining: 521ms
# 104:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 568ms	remaining: 514ms
# 105:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 571ms	remaining: 507ms
# 106:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 576ms	remaining: 500ms
# 107:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 578ms	remaining: 492ms
# 108:	learn: 0.9978070	test: 0.9557522	best: 0.9557522 (75)	total: 581ms	remaining: 485ms
# 109:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 585ms	remaining: 478ms
# 110:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 589ms	remaining: 472ms
# 111:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 593ms	remaining: 466ms
# 112:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 599ms	remaining: 461ms
# 113:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 602ms	remaining: 454ms
# 114:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 606ms	remaining: 448ms
# 115:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 608ms	remaining: 440ms
# 116:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 612ms	remaining: 434ms
# 117:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 616ms	remaining: 428ms
# 118:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 620ms	remaining: 422ms
# 119:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 623ms	remaining: 415ms
# 120:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 626ms	remaining: 408ms
# 121:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 629ms	remaining: 402ms
# 122:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 634ms	remaining: 397ms
# 123:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 637ms	remaining: 391ms
# 124:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 643ms	remaining: 386ms
# 125:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 650ms	remaining: 382ms
# 126:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 656ms	remaining: 377ms
# 127:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 659ms	remaining: 371ms
# 128:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 664ms	remaining: 366ms
# 129:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 669ms	remaining: 360ms
# 130:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 673ms	remaining: 355ms
# 131:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 678ms	remaining: 349ms
# 132:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 682ms	remaining: 344ms
# 133:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 687ms	remaining: 338ms
# 134:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 690ms	remaining: 332ms
# 135:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 695ms	remaining: 327ms
# 136:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 700ms	remaining: 322ms
# 137:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 703ms	remaining: 316ms
# 138:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 706ms	remaining: 310ms
# 139:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 711ms	remaining: 305ms
# 140:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 715ms	remaining: 299ms
# 141:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 718ms	remaining: 293ms
# 142:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 720ms	remaining: 287ms
# 143:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 724ms	remaining: 281ms
# 144:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 729ms	remaining: 276ms
# 145:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 731ms	remaining: 271ms
# 146:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 734ms	remaining: 264ms
# 147:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 736ms	remaining: 258ms
# 148:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 739ms	remaining: 253ms
# 149:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 744ms	remaining: 248ms
# 150:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 746ms	remaining: 242ms
# 151:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 748ms	remaining: 236ms
# 152:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 751ms	remaining: 231ms
# 153:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 753ms	remaining: 225ms
# 154:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 758ms	remaining: 220ms
# 155:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 760ms	remaining: 214ms
# 156:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 763ms	remaining: 209ms
# 157:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 766ms	remaining: 204ms
# 158:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 769ms	remaining: 198ms
# 159:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 772ms	remaining: 193ms
# 160:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 776ms	remaining: 188ms
# 161:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 779ms	remaining: 183ms
# 162:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 783ms	remaining: 178ms
# 163:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 786ms	remaining: 172ms
# 164:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 789ms	remaining: 167ms
# 165:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 791ms	remaining: 162ms
# 166:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 795ms	remaining: 157ms
# 167:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 798ms	remaining: 152ms
# 168:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 800ms	remaining: 147ms
# 169:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 803ms	remaining: 142ms
# 170:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 807ms	remaining: 137ms
# 171:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 810ms	remaining: 132ms
# 172:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 815ms	remaining: 127ms
# 173:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 818ms	remaining: 122ms
# 174:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 824ms	remaining: 118ms
# 175:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 827ms	remaining: 113ms
# 176:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 829ms	remaining: 108ms
# 177:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 832ms	remaining: 103ms
# 178:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 838ms	remaining: 98.4ms
# 179:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 841ms	remaining: 93.5ms
# 180:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 844ms	remaining: 88.6ms
# 181:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 847ms	remaining: 83.8ms
# 182:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 851ms	remaining: 79.1ms
# 183:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 854ms	remaining: 74.3ms
# 184:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 857ms	remaining: 69.5ms
# 185:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 859ms	remaining: 64.7ms
# 186:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 862ms	remaining: 59.9ms
# 187:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 864ms	remaining: 55.1ms
# 188:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 868ms	remaining: 50.5ms
# 189:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 871ms	remaining: 45.9ms
# 190:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 875ms	remaining: 41.2ms
# 191:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 878ms	remaining: 36.6ms
# 192:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 883ms	remaining: 32ms
# 193:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 886ms	remaining: 27.4ms
# 194:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 889ms	remaining: 22.8ms
# 195:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 892ms	remaining: 18.2ms
# 196:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 894ms	remaining: 13.6ms
# 197:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 896ms	remaining: 9.05ms
# 198:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 900ms	remaining: 4.52ms
# 199:	learn: 1.0000000	test: 0.9557522	best: 0.9557522 (75)	total: 903ms	remaining: 0us
#
# bestTest = 0.9557522124
# bestIteration = 75
#
# CatBoost 5-fold accuracy: 0.968 ± 0.012
# Full CV results (last row):
#      iterations  test-Accuracy-mean  test-Accuracy-std  train-Accuracy-mean  \
# 199         199            0.968295           0.012017                  1.0
#
#      train-Accuracy-std  test-Logloss-mean  test-Logloss-std  \
# 199                 0.0           0.086179          0.029148
#
#      train-Logloss-mean  train-Logloss-std
# 199            0.013146           0.001606

# %% [markdown]
# ## 6. PyCaret with the breast-cancer dataset
#
# **Description (conceptual)**
#
# PyCaret abstracts away the explicit CV loop:
#
# - We convert `X, y` into a `pandas.DataFrame`.
# - `setup(..., fold=5, fold_strategy="stratifiedkfold")` configures stratified 5-fold CV globally.
# - `compare_models` trains and evaluates many models using this CV configuration and returns top performers.
# - This is a high-level interface: same dataset and CV strategy, but very little boilerplate.

# %%
import pandas as pd
import pycaret.classification as pc

df = pd.DataFrame(X, columns=data.feature_names)
df["target"] = y

clf = pc.setup(
    data=df,
    target="target",
    fold=5,
    fold_strategy="stratifiedkfold",
    session_id=42,
    silent=True,
    verbose=False
)

best_models = pc.compare_models(sort="AUC", n_select=3)
print(best_models)

# %% [markdown]
# ------
#
# ## 7. H2O with 5-fold stratified CV
#
# **Description (conceptual)**
#
# This shows how an H2O model performs internal cross-validation:
#
# - The breast cancer data is wrapped in an `H2OFrame`.
# - `nfolds=5` and `fold_assignment="Stratified"` instruct the estimator to perform stratified 5-fold CV inside H2O.
# - `model.model_performance(xval=True)` returns cross-validated performance (here AUC).

# %%
import h2o
from h2o.estimators import H2ORandomForestEstimator
import pandas as pd
import numpy as np

h2o.init()

df_h2o = pd.DataFrame(X, columns=data.feature_names)
df_h2o["target"] = y
hf = h2o.H2OFrame(df_h2o)

hf["target"] = hf["target"].asfactor()

model = H2ORandomForestEstimator(
    nfolds=5,
    fold_assignment="Stratified",
    keep_cross_validation_predictions=True,
    seed=42
)

model.train(x=list(data.feature_names), y="target", training_frame=hf)

# Get overall cross-validation accuracy
cv_metrics_summary = model.cross_validation_metrics_summary().as_data_frame()

# Assuming the first column (index 0) contains the metric names like 'accuracy', 'auc', 'err'
# and subsequent columns are 'mean', 'sd', etc.
accuracy_row = cv_metrics_summary[cv_metrics_summary.iloc[:, 0] == 'accuracy']
mean_accuracy_h2o = accuracy_row['mean'].values[0]
std_accuracy_h2o = accuracy_row['sd'].values[0]

print(f"H2O CV Accuracy: {mean_accuracy_h2o:.3f} \u00b1 {std_accuracy_h2o:.3f}")
print("H2O CV AUC (overall):", model.model_performance(xval=True).auc())
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "17.0.18" 2026-01-20; OpenJDK Runtime Environment (build 17.0.18+8-Ubuntu-124.04.1); OpenJDK 64-Bit Server VM (build 17.0.18+8-Ubuntu-124.04.1, mixed mode, sharing)
#   Starting server from /home/amir/Umea_Desctop/AAA_test/p4_CV/P4_paper/Repo/trustcv26012026/.venv/lib/python3.12/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp3s7iv_fi
#   JVM stdout: /tmp/tmp3s7iv_fi/h2o_amir_started_from_python.out
#   JVM stderr: /tmp/tmp3s7iv_fi/h2o_amir_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Europe/Stockholm
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.9
# H2O_cluster_version_age:    2 months and 11 days
# H2O_cluster_name:           H2O_from_python_amir_sznik1
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.806 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.12.3 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# drf Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# H2O CV Accuracy: 0.975 ± 0.024
# H2O CV AUC (overall): 0.9876856402938534

# %% [markdown]
# ## 8. Keras (TensorFlow) with manual stratified K-fold
#
# **Description (conceptual)**
#
# This demonstrates how deep learning fits into the same CV structure:
#
# - We define a small MLP in Keras.
# - We reuse sklearn’s `StratifiedKFold` to generate 5 folds on `X, y`.
# - For each fold:
#   - A fresh model is built and trained.
#   - Accuracy on the held-out fold is recorded.
# - The result is again `mean ± std` accuracy across folds.

# %%
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import os
import random
import numpy as np
import tensorflow as tf

# Optional: reproducibility
seed = 42
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)

def make_keras_model(input_dim):
    model = Sequential([
        Dense(16, activation="relu", input_shape=(input_dim,)),
        Dense(8, activation="relu"),
        Dense(1, activation="sigmoid")
    ])
    model.compile(optimizer=Adam(0.001),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])
    return model


skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
accs = []

for train_idx, test_idx in skf.split(X, y):
    model = make_keras_model(X.shape[1])
    model.fit(X[train_idx], y[train_idx],
              epochs=20, batch_size=32, verbose=0)
    loss, acc = model.evaluate(X[test_idx], y[test_idx], verbose=0)
    accs.append(acc)

accs = np.array(accs)
print(f"Keras 5-fold accuracy: {accs.mean():.3f} ± {accs.std():.3f}")
# Out:
# 2026-02-05 14:35:49.615291: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-05 14:35:49.743179: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-05 14:35:49.903784: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-05 14:35:50.072730: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-05 14:35:50.074608: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-05 14:35:50.453534: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-05 14:35:52.966171: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Keras 5-fold accuracy: 0.863 ± 0.057

# %% [markdown]
# ### Keras (TensorFlow) with stratified K-fold and  `TrustCVValidator`

# %%
from scikeras.wrappers import KerasClassifier

# Optional: reproducibility
seed = 42
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)


def make_keras_model(input_dim):
    model = Sequential([
        Dense(16, activation="relu", input_shape=(input_dim,)),
        Dense(8, activation="relu"),
        Dense(1, activation="sigmoid"),
    ])
    model.compile(optimizer=Adam(0.001), loss="binary_crossentropy", metrics=["accuracy"])
    return model


model = KerasClassifier(
    model=make_keras_model,
    model__input_dim=X.shape[1],
    epochs=20,
    batch_size=32,
    verbose=0,
)

validator = TrustCVValidator(
    method="StratifiedKFold",   # IID, stratified CV
    n_splits=5,
    random_state=42,
    shuffle=True,
    check_leakage=True,
    check_balance=True,
    # metrics=["accuracy", "roc_auc", "f1"],  # optionally specify metrics
    return_confidence_intervals=True,
    ci_method="t-interval",     # 'bootstrap' or 't-interval'
    ci_level=0.95,              # confidence level
)
val_result = validator.validate(model=model, X=X, y=y)
print(val_result.summary())
# Out:
# === Trustworthy Cross-Validation Results ===
#
# Performance Metrics (mean +/- std) (method: t-interval):
#   accuracy: 0.863 +/- 0.064 [95% CI (t-interval): 0.783-0.943]
#   roc_auc: 0.883 +/- 0.037 [95% CI (t-interval): 0.837-0.929]
#   sensitivity: 0.899 +/- 0.099 [95% CI (t-interval): 0.776-1.022]
#   specificity: 0.802 +/- 0.061 [95% CI (t-interval): 0.726-0.879]
#   precision: 0.885 +/- 0.033 [95% CI (t-interval): 0.844-0.925]
#   recall: 0.899 +/- 0.099 [95% CI (t-interval): 0.776-1.022]
#   f1: 0.890 +/- 0.057 [95% CI (t-interval): 0.819-0.961]
#
# Data Integrity Checks:
#   Leakage Check: PASSED
#   Class Balance: PASSED

# %% [markdown]
# ## 9. PyTorch with KFold on the same data
#
# **Description (conceptual)**
#
# Finally, we show the low-level deep learning case with PyTorch:
#
# - `KFold` from sklearn defines 5 folds on `X, y`.
# - The data is wrapped in a `TensorDataset`.
# - For each fold:
#   - We create new `DataLoader`s using index-based samplers for train and test.
#   - A simple feed-forward network is trained for a fixed number of epochs.
#   - Accuracy on the held-out fold is computed.
# - Again we get `accuracy_mean ± accuracy_std` across the 5 folds.

# %%
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader, SubsetRandomSampler
from sklearn.model_selection import KFold
import random

# Optional: reproducibility
seed = 42
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed) 

X_t = torch.tensor(X, dtype=torch.float32)
y_t = torch.tensor(y, dtype=torch.float32).view(-1, 1)
dataset = TensorDataset(X_t, y_t)

class SimpleNet(nn.Module):
    def __init__(self, in_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x)

def train_one_epoch(model, loader, optimizer, loss_fn):
    model.train()
    for xb, yb in loader:
        optimizer.zero_grad()
        preds = model(xb)
        loss = loss_fn(preds, yb)
        loss.backward()
        optimizer.step()

def evaluate_accuracy(model, loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for xb, yb in loader:
            preds = (model(xb) > 0.5).float()
            correct += (preds == yb).sum().item()
            total += yb.size(0)
    return correct / total

kf = KFold(n_splits=5, shuffle=True, random_state=42)
accs_torch = []

for train_idx, test_idx in kf.split(X_t):
    model = SimpleNet(X_t.shape[1])
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_fn = nn.BCELoss()

    train_loader = DataLoader(dataset, batch_size=32,
                              sampler=SubsetRandomSampler(train_idx))
    test_loader = DataLoader(dataset, batch_size=32,
                             sampler=SubsetRandomSampler(test_idx))

    for _ in range(20):
        train_one_epoch(model, train_loader, optimizer, loss_fn)

    acc = evaluate_accuracy(model, test_loader)
    accs_torch.append(acc)

accs_torch = np.array(accs_torch)
print(f"PyTorch 5-fold accuracy: {accs_torch.mean():.3f} ± {accs_torch.std():.3f}")
# Out:
# PyTorch 5-fold accuracy: 0.907 ± 0.040

# %% [markdown]
# #### using `TrustCV`

# %%
import numpy as np
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader, SubsetRandomSampler
from sklearn.base import BaseEstimator, ClassifierMixin
from trustcv import TrustCVValidator

# keep the global seeds at the top of the notebook
seed = 42
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)

class TorchSKClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, input_dim=None, lr=1e-3, epochs=20, batch_size=32, device="cpu", seed=42):
        self.input_dim = input_dim
        self.lr = lr
        self.epochs = epochs
        self.batch_size = batch_size
        self.device = device
        self.seed = seed
        self._gen = torch.Generator().manual_seed(seed)

    def _build_model(self, in_dim):
        return nn.Sequential(
            nn.Linear(in_dim, 16), nn.ReLU(),
            nn.Linear(16, 8), nn.ReLU(),
            nn.Linear(8, 1), nn.Sigmoid(),
        ).to(self.device)

    def fit(self, X, y):
        # do NOT reseed here; let the global RNG advance like your manual loop
        X_t = torch.as_tensor(X, dtype=torch.float32, device=self.device)
        y_t = torch.as_tensor(y, dtype=torch.float32, device=self.device).view(-1, 1)

        self.model_ = self._build_model(self.input_dim or X_t.shape[1])
        opt = torch.optim.Adam(self.model_.parameters(), lr=self.lr)
        loss_fn = nn.BCELoss()

        idx = torch.arange(X_t.shape[0])
        loader = DataLoader(
            TensorDataset(X_t, y_t),
            batch_size=self.batch_size,
            sampler=SubsetRandomSampler(idx, generator=self._gen),  # deterministic across runs
        )

        self.model_.train()
        for _ in range(self.epochs):
            for xb, yb in loader:
                opt.zero_grad()
                loss = loss_fn(self.model_(xb), yb)
                loss.backward()
                opt.step()
        return self

    def predict_proba(self, X):
        self.model_.eval()
        X_t = torch.as_tensor(X, dtype=torch.float32, device=self.device)
        with torch.no_grad():
            probs = self.model_(X_t).cpu().numpy().ravel()
        probs = np.clip(probs, 1e-7, 1 - 1e-7)
        return np.stack([1 - probs, probs], axis=1)

    def predict(self, X):
        return (self.predict_proba(X)[:, 1] >= 0.5).astype(np.float32)
    

est = TorchSKClassifier(input_dim=X.shape[1], epochs=20, batch_size=32, lr=1e-3, seed=42)
validator = TrustCVValidator(method="kfold", n_splits=5, random_state=42, shuffle=True)
val_result = validator.validate(model=est, X=X, y=y)
print(val_result.summary())
# Out:
# === Trustworthy Cross-Validation Results ===
#
# Performance Metrics (mean +/- std) (method: bootstrap):
#   accuracy: 0.900 +/- 0.031 [95% CI (bootstrap): 0.875-0.926]
#   roc_auc: 0.957 +/- 0.029 [95% CI (bootstrap): 0.936-0.979]
#   sensitivity: 0.941 +/- 0.085 [95% CI (bootstrap): 0.864-0.991]
#   specificity: 0.841 +/- 0.096 [95% CI (bootstrap): 0.779-0.924]
#   precision: 0.909 +/- 0.056 [95% CI (bootstrap): 0.873-0.956]
#   recall: 0.941 +/- 0.085 [95% CI (bootstrap): 0.867-0.988]
#   f1: 0.921 +/- 0.027 [95% CI (bootstrap): 0.899-0.943]
#
# Data Integrity Checks:
#   Leakage Check: PASSED
#   Class Balance: PASSED

# %% [markdown]
# ### Diffrence in Performance Metrics
#
# **Determinism risk:** First is fully deterministic per run due to generator=self._gen; second might see minor variability from sampler order because it doesn’t pass an explicit generator.
